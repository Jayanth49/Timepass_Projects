# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Train.csv")
data
# Out:
#       n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0                9.0             286.0         0.552727               1.0
# 1               10.0              96.0         0.702128               1.0
# 2                9.0             399.0         0.675532               1.0
# 3               11.0            1388.0         0.482156               1.0
# 4               12.0             499.0         0.564682               1.0
# ...              ...               ...              ...               ...
# 7923            12.0             260.0         0.596838               1.0
# 7924             8.0             277.0         0.589744               1.0
# 7925            12.0             299.0         0.589831               1.0
# 7926            14.0             449.0         0.542141               1.0
# 7927            11.0             942.0         0.334047               1.0
#
#       n_non_stop_unique_tokens  num_hrefs  num_self_hrefs  num_imgs  \
# 0                     0.612903        6.0             4.0       2.0
# 1                     0.796875        4.0             3.0      10.0
# 2                     0.813433       21.0             1.0      20.0
# 3                     0.685446       40.0             4.0       2.0
# 4                     0.752508       10.0             0.0       1.0
# ...                        ...        ...             ...       ...
# 7923                  0.703704        5.0             2.0       0.0
# 7924                  0.750000        4.0             1.0       1.0
# 7925                  0.673367        8.0             6.0       1.0
# 7926                  0.708633        5.0             4.0       1.0
# 7927                  0.433447       10.0             5.0       7.0
#
#       num_videos  average_token_length  ...  min_positive_polarity  \
# 0            1.0              4.702797  ...               0.136364
# 1            1.0              4.458333  ...               0.200000
# 2            0.0              4.859649  ...               0.100000
# 3            5.0              4.562680  ...               0.033333
# 4            0.0              4.961924  ...               0.100000
# ...          ...                   ...  ...                    ...
# 7923         0.0              4.757692  ...               0.136364
# 7924         0.0              4.833935  ...               0.200000
# 7925         0.0              5.117057  ...               0.136364
# 7926         0.0              4.703786  ...               0.100000
# 7927         0.0              4.407643  ...               0.100000
#
#       max_positive_polarity  avg_negative_polarity  min_negative_polarity  \
# 0                       1.0               0.000000                 0.0000
# 1                       0.5              -0.650000                -0.7000
# 2                       0.6              -0.180208                -0.4000
# 3                       1.0              -0.260965                -0.5000
# 4                       0.6              -0.195238                -0.4000
# ...                     ...                    ...                    ...
# 7923                    0.5              -0.143750                -0.1875
# 7924                    0.6              -0.129422                -0.2000
# 7925                    0.6              -0.277778                -0.5000
# 7926                    0.6              -0.198214                -0.6000
# 7927                    1.0              -0.236869                -0.3000
#
#       max_negative_polarity  title_subjectivity  title_sentiment_polarity  \
# 0                  0.000000            0.000000                  0.000000
# 1                 -0.600000            1.000000                  0.500000
# 2                 -0.100000            0.535714                  0.285714
# 3                 -0.050000            1.000000                 -0.500000
# 4                 -0.100000            0.650000                  0.350000
# ...                     ...                 ...                       ...
# 7923              -0.100000            0.400000                 -0.250000
# 7924              -0.071429            0.500000                  0.500000
# 7925              -0.050000            0.200000                  0.300000
# 7926              -0.066667            0.266667                  0.175000
# 7927              -0.125000            0.700000                  0.366667
#
#       abs_title_subjectivity  abs_title_sentiment_polarity   shares
# 0                   0.500000                      0.000000   4751.0
# 1                   0.500000                      0.500000   1821.0
# 2                   0.035714                      0.285714   1420.0
# 3                   0.500000                      0.500000     52.0
# 4                   0.150000                      0.350000   4182.0
# ...                      ...                           ...      ...
# 7923                0.100000                      0.250000    640.0
# 7924                0.000000                      0.500000    216.0
# 7925                0.300000                      0.300000  18735.0
# 7926                0.233333                      0.175000    739.0
# 7927                0.200000                      0.366667   2001.0
#
# [7928 rows x 59 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7928 entries, 0 to 7927
# Data columns (total 59 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   n_tokens_title                 7928 non-null   float64
#  1   n_tokens_content               7928 non-null   float64
#  2   n_unique_tokens                7928 non-null   float64
#  3   n_non_stop_words               7928 non-null   float64
#  4   n_non_stop_unique_tokens       7928 non-null   float64
#  5   num_hrefs                      7928 non-null   float64
#  6   num_self_hrefs                 7928 non-null   float64
#  7   num_imgs                       7928 non-null   float64
#  8   num_videos                     7928 non-null   float64
#  9   average_token_length           7928 non-null   float64
#  10  num_keywords                   7928 non-null   float64
#  11  data_channel_is_lifestyle      7928 non-null   float64
#  12  data_channel_is_entertainment  7928 non-null   float64
#  13  data_channel_is_bus            7928 non-null   float64
#  14  data_channel_is_socmed         7928 non-null   float64
#  15  data_channel_is_tech           7928 non-null   float64
#  16  data_channel_is_world          7928 non-null   float64
#  17  kw_min_min                     7928 non-null   float64
#  18  kw_max_min                     7928 non-null   float64
#  19  kw_avg_min                     7928 non-null   float64
#  20  kw_min_max                     7928 non-null   float64
#  21  kw_max_max                     7928 non-null   float64
#  22  kw_avg_max                     7928 non-null   float64
#  23  kw_min_avg                     7928 non-null   float64
#  24  kw_max_avg                     7928 non-null   float64
#  25  kw_avg_avg                     7928 non-null   float64
#  26  self_reference_min_shares      7928 non-null   float64
#  27  self_reference_max_shares      7928 non-null   float64
#  28  self_reference_avg_sharess     7928 non-null   float64
#  29  weekday_is_monday              7928 non-null   float64
#  30  weekday_is_tuesday             7928 non-null   float64
#  31  weekday_is_wednesday           7928 non-null   float64
#  32  weekday_is_thursday            7928 non-null   float64
#  33  weekday_is_friday              7928 non-null   float64
#  34  weekday_is_saturday            7928 non-null   float64
#  35  weekday_is_sunday              7928 non-null   float64
#  36  is_weekend                     7928 non-null   float64
#  37  LDA_00                         7928 non-null   float64
#  38  LDA_01                         7928 non-null   float64
#  39  LDA_02                         7928 non-null   float64
#  40  LDA_03                         7928 non-null   float64
#  41  LDA_04                         7928 non-null   float64
#  42  global_subjectivity            7928 non-null   float64
#  43  global_sentiment_polarity      7928 non-null   float64
#  44  global_rate_positive_words     7928 non-null   float64
#  45  global_rate_negative_words     7928 non-null   float64
#  46  rate_positive_words            7928 non-null   float64
#  47  rate_negative_words            7928 non-null   float64
#  48  avg_positive_polarity          7928 non-null   float64
#  49  min_positive_polarity          7928 non-null   float64
#  50  max_positive_polarity          7928 non-null   float64
#  51  avg_negative_polarity          7928 non-null   float64
#  52  min_negative_polarity          7928 non-null   float64
#  53  max_negative_polarity          7928 non-null   float64
#  54  title_subjectivity             7928 non-null   float64
#  55  title_sentiment_polarity       7928 non-null   float64
#  56  abs_title_subjectivity         7928 non-null   float64
#  57  abs_title_sentiment_polarity   7928 non-null   float64
#  58  shares                         7928 non-null   float64
# dtypes: float64(59)
# memory usage: 3.6 MB

# %%
data.describe()
# Out:
#        n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# count     7928.000000       7928.000000      7928.000000       7928.000000
# mean        10.351539        547.278885         0.530738          0.970737
# std          2.081573        465.568556         0.136039          0.168554
# min          4.000000          0.000000         0.000000          0.000000
# 25%          9.000000        247.000000         0.471577          1.000000
# 50%         10.000000        414.000000         0.538462          1.000000
# 75%         12.000000        712.250000         0.609204          1.000000
# max         19.000000       5194.000000         1.000000          1.000000
#
#        n_non_stop_unique_tokens    num_hrefs  num_self_hrefs     num_imgs  \
# count               7928.000000  7928.000000     7928.000000  7928.000000
# mean                   0.673645    10.969980        3.327573     4.520055
# std                    0.152945    11.688543        3.995650     8.169029
# min                    0.000000     0.000000        0.000000     0.000000
# 25%                    0.625657     4.000000        1.000000     1.000000
# 50%                    0.691382     8.000000        3.000000     1.000000
# 75%                    0.754171    14.000000        4.000000     4.000000
# max                    1.000000   161.000000       74.000000   128.000000
#
#         num_videos  average_token_length  ...  min_positive_polarity  \
# count  7928.000000           7928.000000  ...            7928.000000
# mean      1.244576              4.548447  ...               0.094660
# std       3.927641              0.835589  ...               0.071683
# min       0.000000              0.000000  ...               0.000000
# 25%       0.000000              4.479578  ...               0.050000
# 50%       0.000000              4.664902  ...               0.100000
# 75%       1.000000              4.847281  ...               0.100000
# max      75.000000              6.295393  ...               1.000000
#
#        max_positive_polarity  avg_negative_polarity  min_negative_polarity  \
# count            7928.000000            7928.000000            7928.000000
# mean                0.755459              -0.260840              -0.525351
# std                 0.246944               0.127477               0.290651
# min                 0.000000              -1.000000              -1.000000
# 25%                 0.600000              -0.330430              -0.714286
# 50%                 0.800000              -0.253850              -0.500000
# 75%                 1.000000              -0.187500              -0.300000
# max                 1.000000               0.000000               0.000000
#
#        max_negative_polarity  title_subjectivity  title_sentiment_polarity  \
# count            7928.000000         7928.000000               7928.000000
# mean               -0.107692            0.281904                  0.073767
# std                 0.094388            0.325874                  0.266035
# min                -1.000000            0.000000                 -1.000000
# 25%                -0.125000            0.000000                  0.000000
# 50%                -0.100000            0.125000                  0.000000
# 75%                -0.050000            0.500000                  0.150000
# max                 0.000000            1.000000                  1.000000
#
#        abs_title_subjectivity  abs_title_sentiment_polarity         shares
# count             7928.000000                   7928.000000    7928.000000
# mean                 0.344221                      0.156348    7648.628280
# std                  0.187783                      0.227528   27347.647401
# min                  0.000000                      0.000000       1.000000
# 25%                  0.166667                      0.000000    1216.000000
# 50%                  0.500000                      0.000000    2829.000000
# 75%                  0.500000                      0.250000    6127.000000
# max                  0.500000                      1.000000  871713.000000
#
# [8 rows x 59 columns]

# %%
# Total there are 7 outliers first we remove top 3 and test and then we remove remaining 4 and test on our data

data = data[data.shares < 500000]

# %%
num_attributes = ["n_tokens_title","n_tokens_content","n_non_stop_unique_tokens"
                  ,"num_keywords","links","Digital_stuff"
                  ,"kw_max_min","kw_avg_min","kw_min_max","kw_avg_max","kw_min_avg","kw_max_avg","kw_avg_avg"
                  ,"self_reference_min_shares","self_reference_max_shares","self_reference_avg_sharess","LDA_01"
                  ,"LDA_02","LDA_03","LDA_04","global_subjectivity","global_sentiment_polarity","global_rate_positive_words"
                  ,"global_rate_negative_words","rate_positive_words","rate_negative_words","title_subjectivity","title_sentiment_polarity","abs_title_subjectivity"
                  ,"abs_title_sentiment_polarity","max_positivity","min_positivity","avg_positivity","max_negativity"
                 ,"min_negativity","avg_negativity"]
target = ["shares"]
cat_attributes = ["data_channel_is_lifestyle"
                  ,"data_channel_is_tech","data_channel_is_world","is_weekend","non_weekend"]

# "n_non_stop_words","kw_max_max","kw_min_min","average_token_length","n_unique_tokens","LDA_00","weekday_is_monday","weekday_is_tuesday","weekday_is_wednesday"
#                   ,"weekday_is_thursday","weekday_is_friday","weekday_is_saturday","weekday_is_sunday","num_hrefs","num_self_hrefs"
#                   ,"num_imgs","num_videos","data_channel_is_entertainment","data_channel_is_bus","data_channel_is_socmed"
# "avg_positive_polarity"
#                   ,"min_positive_polarity","max_positive_polarity","avg_negative_polarity","min_negative_polarity"
#                   ,"max_negative_polarity",

# %%
data["total_tokens"] = data["n_tokens_title"]+data["n_tokens_content"]
data["non_weekend"] = data["weekday_is_monday"].astype(int) | data["weekday_is_tuesday"].astype(int) | data["weekday_is_wednesday"].astype(int) | data["weekday_is_thursday"].astype(int) | data["weekday_is_friday"].astype(int)
data['links'] = data['num_hrefs']+data['num_self_hrefs']
data['Digital_stuff'] = data['num_imgs']+data['num_videos']
data['max_positivity'] = data['max_positive_polarity']*data['total_tokens']*data['global_rate_positive_words']
data['min_positivity'] = data['min_positive_polarity']*data['total_tokens']*data['global_rate_positive_words']
data['avg_positivity'] = data['avg_positive_polarity']*data['total_tokens']*data['global_rate_positive_words']
data['max_negativity'] = data['max_negative_polarity']*data['total_tokens']*data['global_rate_negative_words']
data['min_negativity'] = data['min_negative_polarity']*data['total_tokens']*data['global_rate_negative_words']
data['avg_negativity'] = data['avg_negative_polarity']*data['total_tokens']*data['global_rate_negative_words']

data = data.drop(["n_non_stop_words","kw_max_max","kw_min_min","average_token_length","n_unique_tokens","LDA_00","weekday_is_monday","weekday_is_tuesday","weekday_is_wednesday"
                  ,"weekday_is_thursday","weekday_is_friday","weekday_is_saturday","weekday_is_sunday","num_hrefs","num_self_hrefs","num_imgs","num_videos"
                  ,"avg_positive_polarity"
                  ,"min_positive_polarity","max_positive_polarity","avg_negative_polarity","min_negative_polarity"
                  ,"max_negative_polarity"],axis=1)
# Out:
# C:\Users\Jayanth\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Jayanth\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Jayanth\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Jayanth\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
corr_matrix = data.corr()
corr_matrix["shares"].sort_values(ascending=False)
# Out:
# shares                           1.000000
# kw_avg_avg                       0.166275
# kw_max_avg                       0.133627
# Digital_stuff                    0.112217
# LDA_03                           0.102307
# kw_min_avg                       0.087713
# global_subjectivity              0.078216
# kw_max_min                       0.075323
# links                            0.070984
# abs_title_sentiment_polarity     0.069691
# kw_avg_min                       0.060232
# kw_min_max                       0.056584
# kw_avg_max                       0.048478
# global_rate_negative_words       0.042729
# self_reference_max_shares        0.041004
# title_subjectivity               0.040275
# avg_positive_polarity            0.038534
# self_reference_avg_sharess       0.032796
# min_positive_polarity            0.026169
# rate_negative_words              0.024225
# is_weekend                       0.021091
# n_tokens_content                 0.020706
# total_tokens                     0.020621
# data_channel_is_socmed           0.019371
# title_sentiment_polarity         0.017556
# self_reference_min_shares        0.017094
# num_keywords                     0.014210
# data_channel_is_lifestyle        0.014020
# global_rate_positive_words       0.012734
# max_positive_polarity            0.010210
# data_channel_is_entertainment   -0.002522
# LDA_01                          -0.010683
# abs_title_subjectivity          -0.012825
# n_tokens_title                  -0.019267
# non_weekend                     -0.021091
# data_channel_is_bus             -0.021445
# LDA_04                          -0.024681
# rate_positive_words             -0.025490
# global_sentiment_polarity       -0.027838
# data_channel_is_tech            -0.030823
# n_non_stop_unique_tokens        -0.031589
# max_negative_polarity           -0.037070
# min_negative_polarity           -0.043029
# data_channel_is_world           -0.055196
# LDA_02                          -0.069215
# avg_negative_polarity           -0.071283
# Name: shares, dtype: float64

# %%
from sklearn.model_selection import train_test_split

train_set,test_set = train_test_split(data,test_size = 0.2,random_state = 0)

x_train = train_set.drop(["shares"],axis=1)
x_train_labels = train_set["shares"]
x_test = test_set.drop(["shares"],axis=1)
x_test_labels = test_set["shares"]
total_train = data.drop(["shares"],axis=1)
total_train_labels = data["shares"]

# %%
from sklearn.base import BaseEstimator, TransformerMixin
class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.attribute_names].values

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline

num_pipeline = Pipeline([
    ('selector', DataFrameSelector(num_attributes)),
    ('std_scalar',MinMaxScaler())
])

cat_pipeline = Pipeline([
    ('selector', DataFrameSelector(cat_attributes))
])


from sklearn.pipeline import FeatureUnion
full_pipeline = FeatureUnion(transformer_list=[
    ("num_pipeline", num_pipeline),
    ("cat_pipeline", cat_pipeline),
])

# %%
x_train_prepared = full_pipeline.fit_transform(x_train)
x_test_prepared = full_pipeline.fit_transform(x_test)
total_train_prepared = full_pipeline.fit_transform(total_train)

# %%
from sklearn.ensemble import GradientBoostingRegressor

reg = GradientBoostingRegressor(loss='lad',criterion='mae',random_state=0)
reg.fit(x_train_prepared,x_train_labels)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='mae', init=None,
#                           learning_rate=0.1, loss='lad', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=0, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
from sklearn.metrics import mean_absolute_error
y = reg.predict(x_train_prepared)
mean_absolute_error(y,x_train_labels)
# Out:
# 5506.692184844063

# %%
y = reg.predict(x_test_prepared)
mean_absolute_error(y,x_test_labels)
# Out:
# 5435.0425788645625

# %%
reg.fit(total_train_prepared,total_train_labels)
y = reg.predict(total_train_prepared)
mean_absolute_error(y,total_train_labels)
# Out:
# 5462.140944070291

# %%
d = pd.read_csv("Test.csv")
d["total_tokens"] = d["n_tokens_title"]+d["n_tokens_content"]
d["non_weekend"] = d["weekday_is_monday"].astype(int) | d["weekday_is_tuesday"].astype(int) | d["weekday_is_wednesday"].astype(int) | d["weekday_is_thursday"].astype(int) | d["weekday_is_friday"].astype(int)
d['links'] = d['num_hrefs']+d['num_self_hrefs']
d['Digital_stuff'] = d['num_imgs']+d['num_videos']

d = d.drop(["n_non_stop_words","kw_max_max","kw_min_min","average_token_length","n_unique_tokens","LDA_00","weekday_is_monday","weekday_is_tuesday","weekday_is_wednesday"
                  ,"weekday_is_thursday","weekday_is_friday","weekday_is_saturday","weekday_is_sunday","num_hrefs","num_self_hrefs","num_imgs","num_videos"],axis=1)

# %%
final_prepared = full_pipeline.fit_transform(d)
y = reg.predict(final_prepared)
output = pd.DataFrame(y,columns=['shares'])
output.to_csv('predicted_version_6.csv',index=False)
p1 = pd.read_csv('predicted_version_6.csv')
p1
# Out:
#             shares
# 0      3813.568942
# 1      3117.406751
# 2      2244.300367
# 3      1711.913691
# 4      2465.348231
# ...            ...
# 31711  3928.593505
# 31712  3969.645542
# 31713  3155.498949
# 31714  2814.778870
# 31715  3105.510873
#
# [31716 rows x 1 columns]
